# %% [markdown]
# # Recurrent Neural Networks in Tensorflow
#
# Main Idea:

# %% [markdown]
# $$y_{(t)} = \phi(W_X^T \cdot x_{(t)} + W_Y^T \cdot y_{(t - 1)} + b)$$

# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
reuse=tf.AUTO_REUSE
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
n_inputs= 3
n_neurons = 5

# %%
X0 = tf.placeholder(tf.float32, [None, n_inputs])
X1 = tf.placeholder(tf.float32, [None, n_inputs])

# %%
Wx = tf.Variable(tf.random_normal(shape = [n_inputs, n_neurons], dtype = tf.float32))
Wy = tf.Variable(tf.random_normal(shape = [n_neurons, n_neurons], dtype = tf.float32))
b = tf.Variable(tf.zeros([1, n_neurons], dtype=tf.float32))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
Y0 = tf.tanh(tf.matmul(X0, Wx) + b)
Y1 = tf.tanh(tf.matmul(Y0, Wy) + tf.matmul(X1, Wx) + b)

# %%
init = tf.global_variables_initializer()

# %%
import numpy as np

# %%
BA = np.array([i for i in np.random.randint(9, size = 12)]).reshape(4,3)

# %%
BB = np.array([i for i in np.random.randint(9, size = 12)]).reshape(4,3)

# %%
BA
# Out:
# array([[8, 0, 5],
#        [5, 0, 4],
#        [5, 1, 5],
#        [5, 7, 6]])

# %%
BB
# Out:
# array([[6, 3, 2],
#        [5, 1, 5],
#        [7, 3, 8],
#        [3, 4, 1]])

# %%
with tf.Session() as sess:
    init.run()
    Y0, Y1 = sess.run([Y0, Y1], feed_dict = {X0: BA, X1: BB})

# %%
Y0
# Out:
# array([[ 1.        ,  0.99999   ,  0.94177306, -0.9999914 ,  0.19447675],
#        [ 1.        ,  0.99991065,  0.9586834 , -0.9998099 , -0.3705316 ],
#        [ 1.        ,  0.9999989 ,  0.99932975, -0.99968857, -0.4521838 ],
#        [ 0.99988925,  1.        ,  1.        ,  0.90813255,  0.9516274 ]],
#       dtype=float32)

# %%
Y1
# Out:
# array([[ 1.        ,  0.9983737 ,  0.99423695,  0.83342695,  0.9996099 ],
#        [ 1.        ,  0.99999744,  0.998912  , -0.99867034,  0.8481053 ],
#        [ 1.        ,  1.        ,  0.9999998 , -0.9997928 ,  0.85679764],
#        [ 0.9780083 ,  0.9876408 ,  0.9996548 ,  0.955523  ,  0.4180172 ]],
#       dtype=float32)

# %% [markdown]
# ## Using Keras

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))

plt.show()

# %%
y_pred = X_valid[:, -1]
np.mean(np.mean((y_pred - y_valid)**2))
# Out:
# 0.020211367

# %%
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %%
np.random.seed(42)
#tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 7000 samples, validate on 2000 samples
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 7000/7000 [==============================] - 0s 40us/sample - loss: 0.0973 - val_loss: 0.0397
# Epoch 2/20
# 7000/7000 [==============================] - 0s 19us/sample - loss: 0.0296 - val_loss: 0.0229
# Epoch 3/20
# 7000/7000 [==============================] - 0s 22us/sample - loss: 0.0194 - val_loss: 0.0175
# Epoch 4/20
# 7000/7000 [==============================] - 0s 22us/sample - loss: 0.0151 - val_loss: 0.0141
# Epoch 5/20
# 7000/7000 [==============================] - 0s 23us/sample - loss: 0.0125 - val_loss: 0.0117
# Epoch 6/20
# 7000/7000 [==============================] - 0s 22us/sample - loss: 0.0106 - val_loss: 0.0099
# Epoch 7/20
# 7000/7000 [==============================] - 0s 21us/sample - loss: 0.0090 - val_loss: 0.0084
# Epoch 8/20
# 7000/7000 [==============================] - 0s 21us/sample - loss: 0.0078 - val_loss: 0.0073
# Epoch 9/20
# 7000/7000 [==============================] - 0s 22us/sample - loss: 0.0068 - val_loss: 0.0063
# Epoch 10/20
# 7000/7000 [==============================] - 0s 21us/sample - loss: 0.0061 - val_loss: 0.0057
# Epoch 11/20
# 7000/7000 [==============================] - 0s 19us/sample - loss: 0.0055 - val_loss: 0.0051
# Epoch 12/20
# 7000/7000 [==============================] - 0s 19us/sample - loss: 0.0051 - val_loss: 0.0047
# Epoch 13/20
# 7000/7000 [==============================] - 0s 23us/sample - loss: 0.0048 - val_loss: 0.0045
# Epoch 14/20
# 7000/7000 [==============================] - 0s 20us/sample - loss: 0.0046 - val_loss: 0.0043
# Epoch 15/20
# 7000/7000 [==============================] - 0s 21us/sample - loss: 0.0044 - val_loss: 0.0042
# Epoch 16/20
# 7000/7000 [==============================] - 0s 20us/sample - loss: 0.0042 - val_loss: 0.0040
# Epoch 17/20
# 7000/7000 [==============================] - 0s 18us/sample - loss: 0.0041 - val_loss: 0.0040
# Epoch 18/20
# 7000/7000 [==============================] - 0s 18us/sample - loss: 0.0040 - val_loss: 0.0038
# Epoch 19/20
# 7000/7000 [==============================] - 0s 19us/sample - loss: 0.0039 - val_loss: 0.0037
# Epoch 20/20
# 7000/7000 [==============================] - 0s 19us/sample - loss: 0.0039 - val_loss: 0.0037

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 8us/sample - loss: 0.0037
# 0.0037153683602809905

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ### Simple RNN

# %%
np.random.seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape = [None, 1])
])

optimizer = keras.optimizers.Adam(lr = 0.005)
model.compile(loss = "mse", optimizer = optimizer)
history = model.fit(X_train, y_train, epochs = 20, 
                    validation_data = (X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 2s 251us/sample - loss: 0.3526 - val_loss: 0.2584
# Epoch 2/20
# 7000/7000 [==============================] - 1s 210us/sample - loss: 0.1733 - val_loss: 0.1234
# Epoch 3/20
# 7000/7000 [==============================] - 1s 205us/sample - loss: 0.0786 - val_loss: 0.0498
# Epoch 4/20
# 7000/7000 [==============================] - 1s 212us/sample - loss: 0.0312 - val_loss: 0.0201
# Epoch 5/20
# 7000/7000 [==============================] - 1s 204us/sample - loss: 0.0151 - val_loss: 0.0124
# Epoch 6/20
# 7000/7000 [==============================] - 1s 208us/sample - loss: 0.0118 - val_loss: 0.0111
# Epoch 7/20
# 7000/7000 [==============================] - 1s 211us/sample - loss: 0.0114 - val_loss: 0.0110
# Epoch 8/20
# 7000/7000 [==============================] - 1s 206us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 9/20
# 7000/7000 [==============================] - 1s 204us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 10/20
# 7000/7000 [==============================] - 1s 203us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 11/20
# 7000/7000 [==============================] - 1s 210us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 7000/7000 [==============================] - 1s 208us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 7000/7000 [==============================] - 1s 213us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 7000/7000 [==============================] - 2s 215us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 7000/7000 [==============================] - 1s 213us/sample - loss: 0.0114 - val_loss: 0.0110
# Epoch 16/20
# 7000/7000 [==============================] - 2s 232us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 7000/7000 [==============================] - 2s 224us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 7000/7000 [==============================] - 2s 221us/sample - loss: 0.0114 - val_loss: 0.0110
# Epoch 19/20
# 7000/7000 [==============================] - 2s 231us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 7000/7000 [==============================] - 2s 250us/sample - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 69us/sample - loss: 0.0109
# 0.010875872172415256

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ### Going Deep

# %%
np.random.seed(42)


model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 6s 796us/sample - loss: 0.0436 - val_loss: 0.0089
# Epoch 2/20
# 7000/7000 [==============================] - 5s 648us/sample - loss: 0.0068 - val_loss: 0.0062
# Epoch 3/20
# 7000/7000 [==============================] - 5s 669us/sample - loss: 0.0049 - val_loss: 0.0044
# Epoch 4/20
# 7000/7000 [==============================] - 5s 654us/sample - loss: 0.0045 - val_loss: 0.0037
# Epoch 5/20
# 7000/7000 [==============================] - 5s 658us/sample - loss: 0.0041 - val_loss: 0.0048
# Epoch 6/20
# 7000/7000 [==============================] - 5s 673us/sample - loss: 0.0039 - val_loss: 0.0038
# Epoch 7/20
# 7000/7000 [==============================] - 5s 692us/sample - loss: 0.0036 - val_loss: 0.0034
# Epoch 8/20
# 7000/7000 [==============================] - 5s 670us/sample - loss: 0.0035 - val_loss: 0.0030
# Epoch 9/20
# 7000/7000 [==============================] - 5s 682us/sample - loss: 0.0033 - val_loss: 0.0033
# Epoch 10/20
# 7000/7000 [==============================] - 5s 676us/sample - loss: 0.0033 - val_loss: 0.0038
# Epoch 11/20
# 7000/7000 [==============================] - 5s 675us/sample - loss: 0.0032 - val_loss: 0.0042
# Epoch 12/20
# 7000/7000 [==============================] - 5s 672us/sample - loss: 0.0032 - val_loss: 0.0033
# Epoch 13/20
# 7000/7000 [==============================] - 5s 666us/sample - loss: 0.0031 - val_loss: 0.0031
# Epoch 14/20
# 7000/7000 [==============================] - 5s 666us/sample - loss: 0.0032 - val_loss: 0.0031
# Epoch 15/20
# 7000/7000 [==============================] - 5s 662us/sample - loss: 0.0032 - val_loss: 0.0039
# Epoch 16/20
# 7000/7000 [==============================] - 5s 663us/sample - loss: 0.0032 - val_loss: 0.0027
# Epoch 17/20
# 7000/7000 [==============================] - 5s 660us/sample - loss: 0.0032 - val_loss: 0.0031
# Epoch 18/20
# 7000/7000 [==============================] - 5s 660us/sample - loss: 0.0031 - val_loss: 0.0028
# Epoch 19/20
# 7000/7000 [==============================] - 5s 692us/sample - loss: 0.0031 - val_loss: 0.0030
# Epoch 20/20
# 7000/7000 [==============================] - 5s 703us/sample - loss: 0.0031 - val_loss: 0.0029

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 197us/sample - loss: 0.0029
# 0.0028744232449680568

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %%
np.random.seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 4s 593us/sample - loss: 0.0246 - val_loss: 0.0048
# Epoch 2/20
# 7000/7000 [==============================] - 3s 451us/sample - loss: 0.0039 - val_loss: 0.0033
# Epoch 3/20
# 7000/7000 [==============================] - 3s 471us/sample - loss: 0.0034 - val_loss: 0.0033
# Epoch 4/20
# 7000/7000 [==============================] - 3s 476us/sample - loss: 0.0032 - val_loss: 0.0028
# Epoch 5/20
# 7000/7000 [==============================] - 3s 499us/sample - loss: 0.0031 - val_loss: 0.0030
# Epoch 6/20
# 7000/7000 [==============================] - 4s 503us/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 7/20
# 7000/7000 [==============================] - 3s 479us/sample - loss: 0.0030 - val_loss: 0.0027
# Epoch 8/20
# 7000/7000 [==============================] - 3s 471us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 9/20
# 7000/7000 [==============================] - 3s 456us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 10/20
# 7000/7000 [==============================] - 3s 458us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 11/20
# 7000/7000 [==============================] - 3s 465us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 12/20
# 7000/7000 [==============================] - 3s 492us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 13/20
# 7000/7000 [==============================] - 3s 488us/sample - loss: 0.0029 - val_loss: 0.0029
# Epoch 14/20
# 7000/7000 [==============================] - 3s 469us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 15/20
# 7000/7000 [==============================] - 3s 467us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 16/20
# 7000/7000 [==============================] - 3s 469us/sample - loss: 0.0028 - val_loss: 0.0027
# Epoch 17/20
# 7000/7000 [==============================] - 3s 472us/sample - loss: 0.0028 - val_loss: 0.0026
# Epoch 18/20
# 7000/7000 [==============================] - 3s 469us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 19/20
# 7000/7000 [==============================] - 3s 466us/sample - loss: 0.0029 - val_loss: 0.0026
# Epoch 20/20
# 7000/7000 [==============================] - 3s 465us/sample - loss: 0.0028 - val_loss: 0.0028

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 116us/sample - loss: 0.0028
# 0.0028079916518181564

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# For a deeper dive into RNN's and Time Series see:
#
# - Geron's Hands on Machine Learning with Tensorflow: https://github.com/ageron/handson-ml/blob/master/14_recurrent_neural_networks.ipynb
